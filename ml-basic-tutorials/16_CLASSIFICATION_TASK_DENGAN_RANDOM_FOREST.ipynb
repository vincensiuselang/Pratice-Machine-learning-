# %% [markdown]
# ## 16 CLASSIFICATION TASK DENGAN RANDOM FOREST

# %% [markdown]
# ![gambar](pertama(16).jpg)

# %% [markdown]
# ![gambar](keduaa(16).jpg)

# %% [markdown]
# ![gambar](keduab(16).jpg)

# %% [markdown]
# ![gambar](ketigaa.jpg)

# %% [markdown]
# ![gambar](keduab(16).jpg)

# %% [markdown]
# ![gambar](keempata.jpg)

# %% [markdown]
# ![gambar](keempat.jpg)

# %% [markdown]
# ## Dataset

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Features: {X.shape}')
print(f'Class: {set(y)}')
# Out:
# Dimensi Features: (150, 4)
# Class: {0, 1, 2}

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0
)

# %% [markdown]
# ## Classification dengan RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, # n_estimators=100 berarti model akan membuat 100 pohon keputusan dan menggabungkan prediksinya.
                              random_state=0)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ## Evaluasi model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
